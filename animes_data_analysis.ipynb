# %% [markdown]
# # Animes Data Analysis

# %% [markdown]
# ### Adding the imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as px

# %% [markdown]
# ### Creating the DataFrame

# %%
df = pd.read_csv("animes.csv")

# %% [markdown]
# ### Reading the data

# %%
df.head()
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
# ...

# %%
df.tail()
# Out:
#          uid                                        title  \
# 19306  32979                                Flip Flappers
# 19307    123                                Fushigi Yuugi
# 19308   1281                             Gakkou no Kaidan
# 19309    450  InuYasha Movie 2: Kagami no Naka no Mugenjo
# 19310     87     Mobile Suit Gundam: Char's Counterattack
#
#                                                 synopsis  \
# 19306  Cocona is an average middle schooler living wi...
# 19307  While visiting the National Library, junior-hi...
# 19308  Years ago, all of the ghosts in a haunted scho...
# 19309  Inuyasha and company have finally destroyed Na...
# 19310  The year is Universal Century 0093. Char Aznab...
#
#                                                    genre  \
# 19306         ['Sci-Fi', 'Adventure', 'Comedy', 'Magic']
# 19307  ['Adventure', 'Fantasy', 'Magic', 'Martial Art...
# 19308              ['Mystery', 'Horror', 'Supernatural']
# ...

# %% [markdown]
# ### Exploring the data

# %%
df.shape
# Out:
# (19311, 12)

# %%
df.columns
# Out:
# Index(['uid', 'title', 'synopsis', 'genre', 'aired', 'episodes', 'members',
#        'popularity', 'ranked', 'score', 'img_url', 'link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19311 entries, 0 to 19310
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         19311 non-null  int64
#  1   title       19311 non-null  object
#  2   synopsis    18336 non-null  object
#  3   genre       19311 non-null  object
#  4   aired       19311 non-null  object
#  5   episodes    18605 non-null  float64
#  6   members     19311 non-null  int64
#  7   popularity  19311 non-null  int64
#  8   ranked      16099 non-null  float64
#  9   score       18732 non-null  float64
#  10  img_url     19131 non-null  object
#  11  link        19311 non-null  object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Filtering and exploring the _null_ values

# %%
df.isnull().sum()
# Out:
# uid              0
# title            0
# synopsis       975
# genre            0
# aired            0
# episodes       706
# members          0
# popularity       0
# ranked        3212
# score          579
# img_url        180
# link             0
# dtype: int64

# %% [markdown]
# ### Data Types

# %%
df.dtypes
# Out:
# uid             int64
# title          object
# synopsis       object
# genre          object
# aired          object
# episodes      float64
# members         int64
# popularity      int64
# ranked        float64
# score         float64
# img_url        object
# link           object
# dtype: object

# %% [markdown]
# ### Dropping columns "img_url" and "link"

# %%
df.drop(["img_url", "link"], inplace = True, axis = 1)

# %%
df.head(2)
# Out:
#      uid                    title  \
# 0  28891  Haikyuu!! Second Season
# 1  23273  Shigatsu wa Kimi no Uso
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
#
#                           aired  episodes  members  popularity  ranked  score
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83

# %% [markdown]
# ### Finding unique uids

# %%
df["uid"].nunique()
# Out:
# 16216

# %% [markdown]
# ## Research Questions

# %% [markdown]
# ### Adding new columns as "start_date" and "end_date"

# %%
df[['start_date', 'end_date']] = df['aired'].str.split(' to ', expand=True)

# %%
df.head(2)
# Out:
#      uid                    title  \
# 0  28891  Haikyuu!! Second Season
# 1  23273  Shigatsu wa Kimi no Uso
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
#
#      start_date      end_date
# 0   Oct 4, 2015  Mar 27, 2016
# 1  Oct 10, 2014  Mar 20, 2015

# %% [markdown]
# ### Adding new columns as "start_year" and "end_year"

# %%
df["start_year"] = df["start_date"].str[-4:]

# %%
df.head(2)
# Out:
#      uid                    title  \
# 0  28891  Haikyuu!! Second Season
# 1  23273  Shigatsu wa Kimi no Uso
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
#
#      start_date      end_date start_year
# 0   Oct 4, 2015  Mar 27, 2016       2015
# 1  Oct 10, 2014  Mar 20, 2015       2014

# %%
df["end_year"] = df["end_date"].str[-4:]

# %%
df.head(2)
# Out:
#      uid                    title  \
# 0  28891  Haikyuu!! Second Season
# 1  23273  Shigatsu wa Kimi no Uso
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
#
#      start_date      end_date start_year end_year
# 0   Oct 4, 2015  Mar 27, 2016       2015     2016
# 1  Oct 10, 2014  Mar 20, 2015       2014     2015

# %% [markdown]
# ### Find all the animes that started and ended in the same year

# %%
df[((df["start_year"]) == (df["end_year"]))]
# Out:
#          uid                               title  \
# 2      34599                       Made in Abyss
# 5      37510                   Mob Psycho 100 II
# 7      38000                    Kimetsu no Yaiba
# 8      35247          Owarimonogatari 2nd Season
# 9       2904  Code Geass: Hangyaku no Lelouch R2
# ...      ...                                 ...
# 19296  22101        Soredemo Sekai wa Utsukushii
# 19297   8795    Panty & Stocking with Garterbelt
# 19298   9510             Mitsudomoe Zouryouchuu!
# 19302   1699                      Romeo x Juliet
# 19306  32979                       Flip Flappers
#
#                                                 synopsis  \
# 2      The Abyss—a gaping chasm stretching down into ...
# 5      Shigeo "Mob" Kageyama is now maturing and unde...
# 7      Ever since the death of his father, the burden...
# 8      Following an encounter with oddity specialist ...
# 9      One year has passed since the Black Rebellion,...
# ...

# %% [markdown]
# ### Find all the animes that have episodes more than 12 and popularity more than 100

# %%
df[(df["episodes"] > 12) & (df["popularity"] > 100)]
# Out:
#          uid                    title  \
# 0      28891  Haikyuu!! Second Season
# 5      37510        Mob Psycho 100 II
# 7      38000         Kimetsu no Yaiba
# 15     15417      Gintama': Enchousen
# 23      1425       Lupin III: Part II
# ...      ...                      ...
# 19304    150                   Blood+
# 19305   4177         Bounen no Xamdou
# 19306  32979            Flip Flappers
# 19307    123            Fushigi Yuugi
# 19308   1281         Gakkou no Kaidan
#
#                                                 synopsis  \
# 0      Following their participation at the Inter-Hig...
# 5      Shigeo "Mob" Kageyama is now maturing and unde...
# 7      Ever since the death of his father, the burden...
# 15     While Gintoki Sakata was away, the Yorozuya fo...
# 23     Lupin III chronicles the adventures of Arsene ...
# ...                                                  ...
# 19304  Saya Otonashi is a seemingly ordinary girl liv...
# ...

# %% [markdown]
# ### Find the number of animes that started and ended each year

# %%
df["start_year"].value_counts()
# Out:
# start_year
# 2017    1047
# 2016    1017
# 2014     994
# 2018     982
# 2015     920
#         ...
# 1953       2
# 1955       2
# 1951       2
# 1944       1
# 1945       1
# Name: count, Length: 101, dtype: int64

# %%
df["end_year"].value_counts()
# Out:
# end_year
# ?       587
# 2017    554
# 2018    544
# 2016    528
# 2015    513
# 2014    465
# 2013    429
# 2012    397
# 2011    368
# 2019    367
# 2010    341
# 2008    339
# 2009    334
# 2006    327
# 2007    323
# 2004    297
# 2003    285
# 2005    252
# 2002    231
# 2001    191
# 1999    162
# 1998    157
# 1997    141
# 2000    140
# 1996    130
# 1995    126
# 1991    103
# 1992     93
# 1990     84
# 1994     82
# 1993     77
# 1989     68
# 1988     59
# 1984     52
# 1985     43
# 1986     39
# 1983     37
# 1987     35
# 1979     35
# 1982     30
# 1981     27
# 1980     27
# 1978     25
# 1977     24
# 1975     23
# 1974     21
# 2020     20
# 1972     20
# 1971     19
# 1968     19
# 1976     18
# 1969     17
# 1973     15
# 1967     15
# 1970     13
# 1966     12
# 1965      9
# 1964      6
# 1962      1
# Name: count, dtype: int64

# %% [markdown]
# ### Find all the animes that started after 2015

# %%
df[df["start_year"] > "2015"]
# Out:
#          uid                                       title  \
# 2      34599                               Made in Abyss
# 4      31758            Kizumonogatari III: Reiketsu-hen
# 5      37510                           Mob Psycho 100 II
# 7      38000                            Kimetsu no Yaiba
# 8      35247                  Owarimonogatari 2nd Season
# ...      ...                                         ...
# 19276  37123             Sora yori mo Tooi Basho: Yokoku
# 19282  34428         Overlord Movie 2: Shikkoku no Eiyuu
# 19285  36038                           Net-juu no Susume
# 19288  32491  Kanojo to Kanojo no Neko: Everything Flows
# 19306  32979                               Flip Flappers
#
#                                                 synopsis  \
# 2      The Abyss—a gaping chasm stretching down into ...
# 4      After helping revive the legendary vampire Kis...
# 5      Shigeo "Mob" Kageyama is now maturing and unde...
# ...

# %% [markdown]
# ### Find all the animes that have the genere as "Mystery" and have episodes more than 12

# %%
df[(df["genre"].str.contains("Mystery")) & (df["episodes"] > 10)]
# Out:
#          uid               title  \
# 2      34599       Made in Abyss
# 20      7588       Saraiya Goyou
# 23      1425  Lupin III: Part II
# 56      1571          Ghost Hunt
# 62       202         Wolf's Rain
# ...      ...                 ...
# 19203  33253     Ajin 2nd Season
# 19259  10620         Mirai Nikki
# 19260  32268    Koyomimonogatari
# 19304    150              Blood+
# 19308   1281    Gakkou no Kaidan
#
#                                                 synopsis  \
# 2      The Abyss—a gaping chasm stretching down into ...
# 20     Masterless samurai Akitsu Masanosuke is a skil...
# 23     Lupin III chronicles the adventures of Arsene ...
# 56     While at school, Taniyama Mai and her friends ...
# 62     In a dying world, there exists an ancient lege...
# ...                                                  ...
# 19203  After escaping certain death, Kei Nagai and hi...
# 19259  Lonely high school student, Yukiteru Amano, sp...
# ...

# %% [markdown]
# ### Find all the details of the anime "Mirai Nikki"

# %%
df[df["title"] == "Mirai Nikki"]
# Out:
#          uid        title                                           synopsis  \
# 1045   10620  Mirai Nikki  Lonely high school student, Yukiteru Amano, sp...
# 19259  10620  Mirai Nikki  Lonely high school student, Yukiteru Amano, sp...
#
#                                                    genre  \
# 1045   ['Action', 'Mystery', 'Psychological', 'Shoune...
# 19259  ['Action', 'Mystery', 'Psychological', 'Shoune...
#
#                              aired  episodes  members  popularity  ranked  \
# 1045   Oct 9, 2011 to Apr 15, 2012      26.0  1205275          13  1043.0
# 19259  Oct 9, 2011 to Apr 15, 2012      26.0  1205275          13  1043.0
#
#        score   start_date      end_date start_year end_year
# 1045    7.74  Oct 9, 2011  Apr 15, 2012       2011     2012
# 19259   7.74  Oct 9, 2011  Apr 15, 2012       2011     2012

# %% [markdown]
# ### Find the top 10 ranked animes

# %%
df[df["ranked"] < 11].sort_values(by = "ranked")
# Out:
#          uid                               title  \
# 3       5114    Fullmetal Alchemist: Brotherhood
# 3080    5114    Fullmetal Alchemist: Brotherhood
# 773     9253                         Steins;Gate
# 18281   9253                         Steins;Gate
# 772    11061              Hunter x Hunter (2011)
# 18280  11061              Hunter x Hunter (2011)
# 771    32281                      Kimi no Na wa.
# 18278  32281                      Kimi no Na wa.
# 770    38524  Shingeki no Kyojin Season 3 Part 2
# 18276  38524  Shingeki no Kyojin Season 3 Part 2
# 769    28977                            Gintama°
# 18067  28977                            Gintama°
# 768     9969                            Gintama'
# 18066   9969                            Gintama'
# 767      820                Ginga Eiyuu Densetsu
# 18065    820                Ginga Eiyuu Densetsu
# 18064  35180          3-gatsu no Lion 2nd Season
# 766    35180          3-gatsu no Lion 2nd Season
# ...

# %% [markdown]
# ### Find all the animes in which the members voted are more than 50,000 and ranked under 100

# %%
df[(df["members"] > 50000) & (df["ranked"] < 100)]
# Out:
#          uid                                          title  \
# 0      28891                        Haikyuu!! Second Season
# 1      23273                        Shigatsu wa Kimi no Uso
# 2      34599                                  Made in Abyss
# 3       5114               Fullmetal Alchemist: Brotherhood
# 4      31758               Kizumonogatari III: Reiketsu-hen
# ...      ...                                            ...
# 18276  38524             Shingeki no Kyojin Season 3 Part 2
# 18278  32281                                 Kimi no Na wa.
# 18280  11061                         Hunter x Hunter (2011)
# 18281   9253                                    Steins;Gate
# 18760    801  Koukaku Kidoutai: Stand Alone Complex 2nd GIG
#
#                                                 synopsis  \
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# 2      The Abyss—a gaping chasm stretching down into ...
# ...

# %% [markdown]
# ### Top 10 animes with most episodes

# %%
df.sort_values(by="episodes", ascending=False).head(10)
# Out:
#          uid                                  title  \
# 11739   9947                                Lan Mao
# 4148   12393                             Oyako Club
# 19265   2471                        Doraemon (1979)
# 1051    2471                        Doraemon (1979)
# 4551   23349                 Kirin Monoshiri Yakata
# 16913   6277     Manga Nippon Mukashibanashi (1976)
# 4432    8213                       Hoka Hoka Kazoku
# 4518   32448               Kirin Ashita no Calendar
# 17245  22221  Monoshiri Daigaku: Ashita no Calendar
# 3323   10241                  Sekai Monoshiri Ryoko
#
#                                                 synopsis  \
# 11739  Adventures include going into deep sea and acc...
# 4148   This anime was running almost 20 years and has...
# 19265  Nobita Nobi is a normal fourth grade student. ...
# 1051   Nobita Nobi is a normal fourth grade student. ...
# 4551                                                 NaN
# ...

# %% [markdown]
# ### Find all the top 15 earliest animes that aired

# %%
df.sort_values(by="start_date").head(10)
# Out:
#          uid                             title  \
# 10538  23651      Hanawa Hekonai Kappa Matsuri
# 12319  28689                    Noroma na Jiji
# 8448    7494                     Usagi to Kame
# 9731   24857  Akagaki Genzou: Tokuri no Wakare
# 7279   34969                             Tsubo
# 7008   27573                       Ubasuteyama
# 8991   29551                    Kanimanji Engi
# 12076   7495    Nonki na Tou-san Ryuuguu Mairi
# 12825  22995                    Shisei Sasshin
# 8172   29555   Kinken Chochiku Shiobara Tasuke
#
#                                                 synopsis               genre  \
# 10538                                                NaN  ['Kids', 'Comedy']
# 12319  An early Noburou Oofuji film, it was artificia...      ['Historical']
# 8448   A retelling of the classic Aesop Fable, The To...         ['Fantasy']
# 9731                                                 NaN          ['Comedy']
# ...

# %%
df.columns
# Out:
# Index(['uid', 'title', 'synopsis', 'genre', 'aired', 'episodes', 'members',
#        'popularity', 'ranked', 'score', 'start_date', 'end_date', 'start_year',
#        'end_year'],
#       dtype='object')

# %% [markdown]
# ## Visual Analysis

# %% [markdown]
# ### Top 10 genres of the animes

# %%
plt.figure(figsize=(10, 6))
sb.countplot(y='genre',hue = "genre", data=df, order=df['genre'].value_counts().index[:10])
plt.title('Genre Distribution')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ### Aired Year Distribution

# %%
plt.figure(figsize=(60, 6))
sb.histplot(df['start_year'], bins=30, kde=True)
plt.title('Aired Year Distribution')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Score Distribution

# %%
plt.figure(figsize=(10, 6))
sb.histplot(df['score'], bins=30, kde=True)
plt.title('Score Distribution')
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Anime timeline distribution

# %%
fig = px.scatter(df, x='start_year', y='end_year', title='Start Year vs. End Year', 
                 labels={'start_year': 'Start Year', 'end_year': 'End Year'},
                 hover_data={'title': True, 'ranked': True})

fig.update_layout(width=1000, height=600)
fig.show()
